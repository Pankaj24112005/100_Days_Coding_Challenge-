# %% [markdown]
# # Day 41 – Matplotlib Basics (Introduction)
#
# This notebook marks the beginning of my journey with **Matplotlib**, a powerful Python library used for data visualization.
#
# **Focus of Day 41:** Understanding fundamentals, purpose, and setup — no plotting yet.

# %% [markdown]
# ## What is Matplotlib?
# Matplotlib is a **Python library** used to create **static, animated, and interactive visualizations**.
#
# It helps transform raw data into meaningful visual insights.

# %% [markdown]
# ##  Why Data Visualization Matters
# - Makes data easier to understand
# - Helps identify patterns and trends
# - Improves decision-making
# - Essential for data science & machine learning

# %% [markdown]
# ##  Matplotlib in the Data Science Ecosystem
# Matplotlib works closely with:
# - NumPy
# - Pandas
# - Seaborn
#
# It forms the foundation for most Python visualization libraries.

# %% [markdown]
# ##  Installing Matplotlib
# If not already installed, use the following command:

# %%
pip install matplotlib

# %% [markdown]
# ##  Importing Matplotlib
# The most common way to import Matplotlib:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ##  Key Takeaways (Day 41)
# - Understood what Matplotlib is
# - Learned why visualization is important
# - Explored how Matplotlib fits into data science
# - Installed and imported the library
