# %% [markdown]
# # Day 86 – Principal Component Analysis (PCA)

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# %%
# Load dataset
data = load_iris()
X = data.data
y = data.target

print("Shape of original data:", X.shape)
# Out:
# Shape of original data: (150, 4)

# %%
# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Apply PCA (reduce to 2 components)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

print("Shape after PCA:", X_pca.shape)
# Out:
# Shape after PCA: (150, 2)

# %%
# Explained variance
print("Explained Variance Ratio:", pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio: [0.72962445 0.22850762]

# %%
# Visualize PCA result
plt.figure()
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA Visualization")
plt.show()

# %% [markdown]
# ## 📌 Conclusion
# - PCA reduces dimensionality while preserving important information.
# - Helps in visualization and improves model efficiency.
# - Widely used in preprocessing for ML models.
