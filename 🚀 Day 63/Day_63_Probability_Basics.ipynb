# %% [markdown]
# # Day 63 – Probability Basics

# %%
favorable_outcomes = 1
total_outcomes = 2
probability = favorable_outcomes / total_outcomes
probability
# Out:
# 0.5

# %% [markdown]
# ## Sample Space & Events

# %%
sample_space = [1,2,3,4,5,6]
event_even = [2,4,6]
len(event_even)/len(sample_space)
# Out:
# 0.5

# %% [markdown]
# ## Independent Events

# %%
P_A=0.5
P_B=0.5
P_A*P_B
# Out:
# 0.25

# %% [markdown]
# ## Empirical Probability

# %%
import random
rolls=[random.randint(1,6) for _ in range(1000)]
rolls.count(6)/len(rolls)
# Out:
# 0.16

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.hist(rolls, bins=6)
plt.title("Day 63 – Probability Basics: Distribution of Dice Rolls")
plt.xlabel("Dice Number")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Conclusion
# Probability is foundation of Data Science & ML.
